# %%
import os
from datetime import datetime
import pandas as pd

# %%
source_file_path = os.path.join(os.curdir, "company_exports_bronze.csv")

# %%
limpiar_bronce_df = pd.read_csv(source_file_path)

# %%
limpiar_bronce_df.head()
# Out:
#    Unnamed: 0   Name Financial Status                    Paid at  \
# 0           0  #5594             paid  2025-11-03 12:19:02 +0100
# 1           1  #5593             paid  2025-11-03 11:19:44 +0100
# 2           2  #5592             paid  2025-11-03 10:11:08 +0100
# 3           3  #5591             paid  2025-11-03 09:20:07 +0100
# 4           4  #5590             paid  2025-11-03 08:39:30 +0100
#
#   Fulfillment Status Fulfilled at Accepts Marketing Currency  Subtotal  \
# 0        unfulfilled          NaN                no      EUR     47.40
# 1        unfulfilled          NaN               yes      EUR     62.78
# 2        unfulfilled          NaN               yes      EUR     28.44
# 3        unfulfilled          NaN               yes      EUR     45.82
# 4        unfulfilled          NaN               yes      EUR     45.00
#
#    Shipping  ...  Shipping Province Name  Payment Terms Name  \
# 0      3.99  ...                     NaN                 NaN
# ...

# %%
limpiar_bronce_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5733 entries, 0 to 5732
# Data columns (total 69 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   5733 non-null   int64
#  1   Name                         5733 non-null   object
#  2   Financial Status             4594 non-null   object
#  3   Paid at                      4592 non-null   object
#  4   Fulfillment Status           4594 non-null   object
#  5   Fulfilled at                 4587 non-null   object
#  6   Accepts Marketing            4594 non-null   object
#  7   Currency                     4594 non-null   object
#  8   Subtotal                     4594 non-null   float64
#  9   Shipping                     4594 non-null   float64
#  10  Taxes                        4594 non-null   float64
#  11  Total                        4594 non-null   float64
#  12  Discount Code                133 non-null    object
# ...

# %%
limpiar_bronce_df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Financial Status', 'Paid at',
#        'Fulfillment Status', 'Fulfilled at', 'Accepts Marketing', 'Currency',
#        'Subtotal', 'Shipping', 'Taxes', 'Total', 'Discount Code',
#        'Discount Amount', 'Shipping Method', 'Created at', 'Lineitem quantity',
#        'Lineitem name', 'Lineitem price', 'Lineitem compare at price',
#        'Lineitem sku', 'Lineitem requires shipping', 'Lineitem taxable',
#        'Lineitem fulfillment status', 'Billing City', 'Billing Zip',
#        'Billing Province', 'Billing Country', 'Shipping City', 'Shipping Zip',
#        'Shipping Province', 'Shipping Country', 'Notes', 'Note Attributes',
#        'Cancelled at', 'Payment Method', 'Refunded Amount', 'Vendor',
#        'Outstanding Balance', 'Employee', 'Location', 'Device ID', 'Tags',
#        'Risk Level', 'Source', 'Lineitem discount', 'Tax 1 Name',
#        'Tax 1 Value', 'Tax 2 Name', 'Tax 2 Value', 'Tax 3 Name', 'Tax 3 Value',
# ...
